# %% [markdown]
# # RegressionVisualizer3D
#
# This a demonstration of the RegressionVisualizer3D package. The package is for visualizing linear regression, Poisson regression and binary logistic regression in 3D, for teaching purposes.
#
# The PyPI project directory for the `RegressionVisualizer3D` package is here: https://pypi.org/project/RegressionVisualizer3D/
#
# The package can be installed with `pip install RegressionVisualizer3D`.
#
#
# # Model plot (default parameters)
#
# The `model_plot()` function generates visualizations of several types of regression model. It uses a data-generating process with specific (user-controlled) parameters to generate population data. A sample (of a size controlled by the user) is then randomly drawn from the population data, and a regression model is fit to that sample. If the user does not supply population parameters, defaults are used.
#
# The cell below runs the `model_plot()` function with its default parameters.

# %%
# importing the package
import RegressionVisualizer3D

# generate and plot the data and regression surfaces, using all default settings
RegressionVisualizer3D.model_plot()
# Out:
# <b>3D linear regression visualizer: </b>
# The lefthand graph below shows some population data and the population regression surface for that data. (E.g. if a regression model were fit to all of the population data).
# The righthand graph shows data from a sample which was randomly drawn from the population data. It also shows the sample regression surface (e.g. from a regression model fit to the sample data).
# Beneath the graphs is the regression table (with slopes and p-values etc.) from the sample data. The true population regression equation used to generate the data is also shown.
# <b> Sample regression table: </b>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Outcome Variable   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     1056.
# Date:                Wed, 13 Jul 2022   Prob (F-statistic):           2.35e-73
# Time:                        13:47:39   Log-Likelihood:                -137.63
# No. Observations:                 100   AIC:                             283.3
# Df Residuals:                      96   BIC:                             293.7
# Df Model:                           3
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         1.2787      0.098     13.023      0.000       1.084       1.474
# Predictor 1                   0.2196      0.051      4.317      0.000       0.119       0.321
# Predictor 2                   3.0962      0.055     56.196      0.000       2.987       3.206
# Predictor 1 * Predictor 2    -0.0575      0.029     -2.009      0.047      -0.114      -0.001
# ==============================================================================
# Omnibus:                        3.181   Durbin-Watson:                   2.278
# Prob(Omnibus):                  0.204   Jarque-Bera (JB):                3.028
# Skew:                          -0.362   Prob(JB):                        0.220
# Kurtosis:                       2.549   Cond. No.                         3.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# <b>True population regression equation:</b>
# $\displaystyle \Large Y = 1 + 0.2  X_1 + 3  X_2 + 0  X_1 X_2 + \epsilon$
# Where:
#  $Y$: Outcome Variable
#  $X_1$: Predictor 1
#  $X_2$: Predictor 2

# %% [markdown]
# # Poisson regression plot (default parameters)
#
# The cell below runs the `model_plot()` function to visualize a Poisson regression, using the default parameters.

# %%
RegressionVisualizer3D.model_plot(model_type = 'poisson_regression')
# Out:
# <b>3D poisson regression visualizer: </b>
# The lefthand graph below shows some population data and the population regression surface for that data. (E.g. if a regression model were fit to all of the population data).
# The righthand graph shows data from a sample which was randomly drawn from the population data. It also shows the sample regression surface (e.g. from a regression model fit to the sample data).
# Beneath the graphs is the regression table (with slopes and p-values etc.) from the sample data. The true population regression equation used to generate the data is also shown.
# <b> Sample regression table: </b>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:       Outcome Variable   No. Observations:                  100
# Model:                            GLM   Df Residuals:                       96
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -156.70
# Date:                Wed, 13 Jul 2022   Deviance:                       5.2197
# Time:                        13:47:40   Pearson chi2:                     5.26
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.9953
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.9954      0.077     12.898      0.000       0.844       1.147
# Predictor 1                   0.6169      0.037     16.670      0.000       0.544       0.689
# Predictor 2                   0.2048      0.049      4.149      0.000       0.108       0.302
# Predictor 1 * Predictor 2    -0.0041      0.023     -0.180      0.857      -0.048       0.040
# =============================================================================================
# """
# <b>True population regression equation:</b>
# $\displaystyle \Large ln(Y) = 1 + 0.6  X_1 + 0.2  X_2 + 0  X_1 X_2 + \epsilon$
# Where:
#  $Y$: Outcome Variable
#  $X_1$: Predictor 1
#  $X_2$: Predictor 2

# %% [markdown]
# # Binary logistic regression plot (default paramters)
#
# The cell below runs the `model_plot()` function to visualize a Binary logistic regression, using the default parameters.

# %%
RegressionVisualizer3D.model_plot(model_type = 'binary_logistic_regression')
# Out:
# <b>3D binary logistic regression visualizer: </b>
# The lefthand graph below shows some population data and the population regression surface for that data. (E.g. if a regression model were fit to all of the population data).
# The righthand graph shows data from a sample which was randomly drawn from the population data. It also shows the sample regression surface (e.g. from a regression model fit to the sample data).
# Beneath the graphs is the regression table (with slopes and p-values etc.) from the sample data. The true population regression equation used to generate the data is also shown.
# Optimization terminated successfully.
#          Current function value: 0.134553
#          Iterations 10
# <b> Sample regression table: </b>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       Outcome Variable   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       96
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 13 Jul 2022   Pseudo R-squ.:                  0.7731
# Time:                        13:47:40   Log-Likelihood:                -13.455
# converged:                       True   LL-Null:                       -59.295
# Covariance Type:            nonrobust   LLR p-value:                 9.543e-20
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         4.2524      1.440      2.954      0.003       1.431       7.074
# Predictor 1                   3.1789      0.939      3.385      0.001       1.338       5.020
# Predictor 2                   2.2605      0.879      2.571      0.010       0.537       3.983
# Predictor 1 * Predictor 2    -0.0350      0.271     -0.129      0.897      -0.566       0.496
# =============================================================================================
#
# Possibly complete quasi-separation: A fraction 0.29 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """
# <b>True population regression equation:</b>
# $\displaystyle \Large logit(Y) = 1 + 0.7  X_1 + 0.5  X_2 + 0  X_1 X_2 + \epsilon$
# Where:
#  $Y$: Outcome Variable
#  $X_1$: Predictor 1
#  $X_2$: Predictor 2

# %% [markdown]
# # Model plots with custom paramters
#
# The cells below show how the user can tweak the parameters of the data-generating process, to see the effect this has on the population and sample data, and on the regression surfaces.
#
# ## Linear regression

# %%
# with custom parameters, controlling the data-generating process
RegressionVisualizer3D.model_plot(model_type = 'linear_regression',
                       intercept = 20,
                       predictor1_slope = 0.8, 
                       predictor2_slope = 3, 
                       interaction_slope = 0.9,
                       sample_size = 30,
                       population_size = 3000,
                       error_sd = 20,
                       predictor1_name = 'Predictor 1',
                       predictor2_name = 'Predictor 2',
                       outcome_variable_name = 'Outcome Variable',
                       axis_size = 10)
# Out:
# <b>3D linear regression visualizer: </b>
# The lefthand graph below shows some population data and the population regression surface for that data. (E.g. if a regression model were fit to all of the population data).
# The righthand graph shows data from a sample which was randomly drawn from the population data. It also shows the sample regression surface (e.g. from a regression model fit to the sample data).
# Beneath the graphs is the regression table (with slopes and p-values etc.) from the sample data. The true population regression equation used to generate the data is also shown.
# <b> Sample regression table: </b>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Outcome Variable   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     58.74
# Date:                Wed, 13 Jul 2022   Prob (F-statistic):           1.03e-11
# Time:                        13:47:41   Log-Likelihood:                -125.46
# No. Observations:                  30   AIC:                             258.9
# Df Residuals:                      26   BIC:                             264.5
# Df Model:                           3
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        17.6387      3.140      5.617      0.000      11.183      24.094
# Predictor 1                   0.6020      0.564      1.068      0.295      -0.557       1.761
# Predictor 2                   3.4939      0.506      6.905      0.000       2.454       4.534
# Predictor 1 * Predictor 2     0.9428      0.090     10.469      0.000       0.758       1.128
# ==============================================================================
# Omnibus:                        2.924   Durbin-Watson:                   1.541
# Prob(Omnibus):                  0.232   Jarque-Bera (JB):                2.279
# Skew:                           0.673   Prob(JB):                        0.320
# Kurtosis:                       2.895   Cond. No.                         37.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# <b>True population regression equation:</b>
# $\displaystyle \Large Y = 20 + 0.8  X_1 + 3  X_2 + 0.9  X_1 X_2 + \epsilon$
# Where:
#  $Y$: Outcome Variable
#  $X_1$: Predictor 1
#  $X_2$: Predictor 2

# %% [markdown]
# ## Poisson regression

# %%
# with custom parameters, controlling the data-generating process
RegressionVisualizer3D.model_plot(model_type = 'poisson_regression',
                       intercept = 0,
                       predictor1_slope = 0, 
                       predictor2_slope = 0.03, 
                       interaction_slope = 0.02,
                       sample_size = 30,
                       population_size = 2500,
                       error_sd = 0.1,
                       predictor1_name = 'Predictor 1',
                       predictor2_name = 'Predictor 2',
                       outcome_variable_name = 'Outcome Variable',
                       axis_size = 10)
# Out:
# <b>3D poisson regression visualizer: </b>
# The lefthand graph below shows some population data and the population regression surface for that data. (E.g. if a regression model were fit to all of the population data).
# The righthand graph shows data from a sample which was randomly drawn from the population data. It also shows the sample regression surface (e.g. from a regression model fit to the sample data).
# Beneath the graphs is the regression table (with slopes and p-values etc.) from the sample data. The true population regression equation used to generate the data is also shown.
# <b> Sample regression table: </b>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:       Outcome Variable   No. Observations:                   30
# Model:                            GLM   Df Residuals:                       26
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -28.534
# Date:                Wed, 13 Jul 2022   Deviance:                      0.19597
# Time:                        13:47:41   Pearson chi2:                    0.198
# No. Iterations:                     4   Pseudo R-squ. (CS):             0.4455
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        -0.0209      0.200     -0.105      0.917      -0.413       0.371
# Predictor 1                  -0.0023      0.031     -0.073      0.942      -0.064       0.059
# Predictor 2                   0.0318      0.031      1.019      0.308      -0.029       0.093
# Predictor 1 * Predictor 2     0.0201      0.005      4.111      0.000       0.011       0.030
# =============================================================================================
# """
# <b>True population regression equation:</b>
# $\displaystyle \Large ln(Y) = 0 + 0  X_1 + 0.03  X_2 + 0.02  X_1 X_2 + \epsilon$
# Where:
#  $Y$: Outcome Variable
#  $X_1$: Predictor 1
#  $X_2$: Predictor 2

# %% [markdown]
# ## Logistic regression

# %%
# with custom parameters, controlling the data-generating process
RegressionVisualizer3D.model_plot(model_type = 'binary_logistic_regression',
                       intercept = 0,
                       predictor1_slope = 0.02, 
                       predictor2_slope = 0.01, 
                       interaction_slope = 0.1,
                       sample_size = 20,
                       population_size = 100,
                       error_sd = 5,
                       predictor1_name = 'Predictor 1',
                       predictor2_name = 'Predictor 2',
                       outcome_variable_name = 'Outcome Variable',
                       axis_size = 10)
# Out:
# <b>3D binary logistic regression visualizer: </b>
# The lefthand graph below shows some population data and the population regression surface for that data. (E.g. if a regression model were fit to all of the population data).
# The righthand graph shows data from a sample which was randomly drawn from the population data. It also shows the sample regression surface (e.g. from a regression model fit to the sample data).
# Beneath the graphs is the regression table (with slopes and p-values etc.) from the sample data. The true population regression equation used to generate the data is also shown.
# Optimization terminated successfully.
#          Current function value: 0.413570
#          Iterations 7
# <b> Sample regression table: </b>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       Outcome Variable   No. Observations:                   20
# Model:                          Logit   Df Residuals:                       16
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 13 Jul 2022   Pseudo R-squ.:                  0.3612
# Time:                        13:47:42   Log-Likelihood:                -8.2714
# converged:                       True   LL-Null:                       -12.949
# Covariance Type:            nonrobust   LLR p-value:                   0.02492
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.7441      0.784      0.949      0.343      -0.793       2.282
# Predictor 1                   0.0030      0.146      0.021      0.983      -0.283       0.289
# Predictor 2                  -0.2337      0.153     -1.524      0.127      -0.534       0.067
# Predictor 1 * Predictor 2     0.0609      0.032      1.881      0.060      -0.003       0.124
# =============================================================================================
# """
# <b>True population regression equation:</b>
# $\displaystyle \Large logit(Y) = 0 + 0.02  X_1 + 0.01  X_2 + 0.1  X_1 X_2 + \epsilon$
# Where:
#  $Y$: Outcome Variable
#  $X_1$: Predictor 1
#  $X_2$: Predictor 2
